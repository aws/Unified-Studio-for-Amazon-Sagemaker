# %%
# Parameters cell
test_param = "default_value"

# %%
import boto3
import datetime

print("="*50)
print(f"Execution Start Time: {datetime.datetime.now()}")
print("="*50)

# Print current role
sts = boto3.client('sts')
caller_identity = sts.get_caller_identity()
print(f"Current Role ARN: {caller_identity['Arn']}")
print(f"Account: {caller_identity['Account']}")
print(f"User ID: {caller_identity['UserId']}")
print("="*50)

# %%
print("Starting failing notebook...")
print(f"Test parameter: {test_param}")

# %%
# This cell will throw an exception
raise ValueError("Intentional failure for testing error handling")

# %%
# This cell should never be reached
print("This should not be printed")
