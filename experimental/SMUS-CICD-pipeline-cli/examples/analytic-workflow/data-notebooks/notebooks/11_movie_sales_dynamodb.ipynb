# %%
import os
print(f"IMAGE_VERSION: {os.environ.get('IMAGE_VERSION', 'Not set')}")
print(f"SAGEMAKER_INTERNAL_IMAGE_URI: {os.environ.get('SAGEMAKER_INTERNAL_IMAGE_URI', 'Not set')}")

# %%
from datetime import datetime
from zoneinfo import ZoneInfo
print(f"Execution Start Time (EST): {datetime.now(ZoneInfo('America/New_York')).strftime('%Y-%m-%d %H:%M:%S %Z')}")

# %%
# Package upgrade skipped - using environment default
print('Using default sagemaker_studio package from environment')

# %% [markdown]
# # Test 11: Exploring Movie Ticket Sales with DynamoDB
#
# This notebook performs some data analytics on movie ticket sales to predict future sales

# %%
from sagemaker_studio import sqlutils

# %%
import boto3from datetime import datetime# Print execution infoprint(f"Execution started at: {datetime.now()}")# Get current IAM rolests = boto3.client('sts')identity = sts.get_caller_identity()print(f"Current Role ARN: {identity['Arn']}")print(f"Account ID: {identity['Account']}")
# Out:
# Movie Ticket Sales Dataset Created!
# Shape: (1000, 26)
#
# Columns: ['movie_id', 'genre', 'rating', 'studio', 'theater_chain', 'release_date', 'budget_millions', 'star_power_score', 'director_reputation', 'sequel_flag', 'franchise_flag', 'marketing_spend_millions', 'num_theaters', 'num_screens', 'is_summer_release', 'is_holiday_release', 'is_weekend_release', 'num_competing_movies', 'avg_competitor_rating', 'social_media_mentions_k', 'critic_score', 'audience_score', 'avg_ticket_price', 'premium_format_pct', 'urban_theater_pct', 'ticket_sales_millions']
#
# Target variable statistics:
# count    1000.000000
# mean       89.138230
# std        25.186165
# min        26.050000
# 25%        72.065000
# 50%        87.465000
# 75%       103.602500
# max       304.280000
# Name: ticket_sales_millions, dtype: float64
#
# Sample records:
#      movie_id     genre  ... urban_theater_pct ticket_sales_millions
# 0  MOVIE_0001    Comedy  ...             0.797                 60.86
# 1  MOVIE_0002    Sci-Fi  ...             0.426                 88.19
# 2  MOVIE_0003    Horror  ...             0.413                 71.32
# 3  MOVIE_0004    Horror  ...             0.406                 76.80
# 4  MOVIE_0005  Thriller  ...             0.755                 81.04
#
# [5 rows x 26 columns]

# %%
import boto3
import pandas as pd
from botocore.exceptions import ClientError
import json
from decimal import Decimal

# Initialize DynamoDB resource
dynamodb = boto3.resource('dynamodb')
table_name = 'movies'

# Check if table exists, if not create it
def create_table_if_not_exists():
    try:
        table = dynamodb.Table(table_name)
        table.load()  # This will raise an exception if table doesn't exist
        print(f"Table '{table_name}' already exists")
        return table
    except ClientError as e:
        if e.response['Error']['Code'] == 'ResourceNotFoundException':
            print(f"Table '{table_name}' not found. Creating table...")
            
            # Create table with movie_id as primary key
            table = dynamodb.create_table(
                TableName=table_name,
                KeySchema=[
                    {
                        'AttributeName': 'movie_id',
                        'KeyType': 'HASH'  # Partition key
                    }
                ],
                AttributeDefinitions=[
                    {
                        'AttributeName': 'movie_id',
                        'AttributeType': 'S'  # String
                    }
                ],
                BillingMode='PAY_PER_REQUEST'  # On-demand billing
            )
            
            # Wait for table to be created
            print("Waiting for table to be created...")
            table.wait_until_exists()
            print(f"Table '{table_name}' created successfully!")
            return table
        else:
            raise e

# Helper function to convert pandas dtypes to DynamoDB compatible types
def convert_to_dynamodb_format(value):
    if pd.isna(value):
        return None
    elif isinstance(value, (int, float)):
        return Decimal(str(value))
    elif isinstance(value, bool):
        return bool(value)
    else:
        return str(value)

# Create table if it doesn't exist
table = create_table_if_not_exists()

# Convert dataframe to DynamoDB items
items_to_write = []
for index, row in df.iterrows():
    item = {}
    for column in df.columns:
        converted_value = convert_to_dynamodb_format(row[column])
        if converted_value is not None:  # Only add non-null values
            item[column] = converted_value
    items_to_write.append(item)

# Batch write items to DynamoDB (DynamoDB batch_writer handles batching automatically)
print(f"Writing {len(items_to_write)} items to DynamoDB table '{table_name}'...")

with table.batch_writer() as batch:
    for item in items_to_write:
        batch.put_item(Item=item)

print(f"Successfully wrote {len(items_to_write)} items to DynamoDB table '{table_name}'!")

# Verify by scanning a few items
print("\nFirst 5 items in the table:")
response = table.scan(Limit=5)
for i, item in enumerate(response['Items'], 1):
    print(f"Item {i}: {dict(item)}")
# Out:
# Table 'movies' not found. Creating table...
# Waiting for table to be created...
# Table 'movies' created successfully!
# Writing 1000 items to DynamoDB table 'movies'...
# Successfully wrote 1000 items to DynamoDB table 'movies'!
#
# First 5 items in the table:
# Item 1: {'movie_id': 'MOVIE_0251', 'marketing_spend_millions': Decimal('3.75'), 'avg_ticket_price': Decimal('14.01'), 'avg_competitor_rating': Decimal('7.4'), 'num_competing_movies': Decimal('3'), 'premium_format_pct': Decimal('0.333'), 'budget_millions': Decimal('11.22'), 'social_media_mentions_k': Decimal('5.8'), 'num_screens': Decimal('2297'), 'director_reputation': Decimal('2'), 'num_theaters': Decimal('1826'), 'rating': 'NR', 'theater_chain': 'Century', 'franchise_flag': Decimal('0'), 'studio': 'Paramount', 'is_weekend_release': Decimal('0'), 'genre': 'Horror', 'is_summer_release': Decimal('0'), 'star_power_score': Decimal('7'), 'release_date': '2025-04-11', 'urban_theater_pct': Decimal('0.595'), 'is_holiday_release': Decimal('0'), 'audience_score': Decimal('79.7'), 'critic_score': Decimal('61.1'), 'ticket_sales_millions': Decimal('52.9'), 'sequel_flag': Decimal('0')}
# Item 2: {'movie_id': 'MOVIE_0686', 'marketing_spend_millions': Decimal('20.51'), 'avg_ticket_price': Decimal('14.89'), 'avg_competitor_rating': Decimal('8.2'), 'num_competing_movies': Decimal('4'), 'premium_format_pct': Decimal('0.424'), 'budget_millions': Decimal('35.68'), 'social_media_mentions_k': Decimal('11'), 'num_screens': Decimal('7440'), 'director_reputation': Decimal('6'), 'num_theaters': Decimal('3373'), 'rating': 'PG-13', 'theater_chain': 'Showcase', 'franchise_flag': Decimal('0'), 'studio': 'Sony', 'is_weekend_release': Decimal('0'), 'genre': 'Comedy', 'is_summer_release': Decimal('0'), 'star_power_score': Decimal('5'), 'release_date': '2024-10-07', 'urban_theater_pct': Decimal('0.739'), 'is_holiday_release': Decimal('0'), 'audience_score': Decimal('92.4'), 'critic_score': Decimal('14.8'), 'ticket_sales_millions': Decimal('88.95'), 'sequel_flag': Decimal('0')}
# Item 3: {'movie_id': 'MOVIE_0634', 'marketing_spend_millions': Decimal('12.46'), 'avg_ticket_price': Decimal('12.73'), 'avg_competitor_rating': Decimal('5.7'), 'num_competing_movies': Decimal('5'), 'premium_format_pct': Decimal('0.184'), 'budget_millions': Decimal('24.93'), 'social_media_mentions_k': Decimal('17.9'), 'num_screens': Decimal('2839'), 'director_reputation': Decimal('9'), 'num_theaters': Decimal('1553'), 'rating': 'R', 'theater_chain': 'AMC', 'franchise_flag': Decimal('0'), 'studio': 'Disney', 'is_weekend_release': Decimal('1'), 'genre': 'Documentary', 'is_summer_release': Decimal('0'), 'star_power_score': Decimal('9'), 'release_date': '2024-01-07', 'urban_theater_pct': Decimal('0.456'), 'is_holiday_release': Decimal('0'), 'audience_score': Decimal('26.7'), 'critic_score': Decimal('23.5'), 'ticket_sales_millions': Decimal('89.88'), 'sequel_flag': Decimal('1')}
# Item 4: {'movie_id': 'MOVIE_0940', 'marketing_spend_millions': Decimal('11.59'), 'avg_ticket_price': Decimal('9.95'), 'avg_competitor_rating': Decimal('6.8'), 'num_competing_movies': Decimal('7'), 'premium_format_pct': Decimal('0.292'), 'budget_millions': Decimal('27.96'), 'social_media_mentions_k': Decimal('11.5'), 'num_screens': Decimal('8517'), 'director_reputation': Decimal('7'), 'num_theaters': Decimal('3623'), 'rating': 'NR', 'theater_chain': 'Marcus', 'franchise_flag': Decimal('0'), 'studio': 'Disney', 'is_weekend_release': Decimal('0'), 'genre': 'Documentary', 'is_summer_release': Decimal('0'), 'star_power_score': Decimal('6'), 'release_date': '2024-10-22', 'urban_theater_pct': Decimal('0.673'), 'is_holiday_release': Decimal('0'), 'audience_score': Decimal('65.9'), 'critic_score': Decimal('82.7'), 'ticket_sales_millions': Decimal('89.92'), 'sequel_flag': Decimal('0')}
# Item 5: {'movie_id': 'MOVIE_0189', 'marketing_spend_millions': Decimal('2.63'), 'avg_ticket_price': Decimal('9.08'), 'avg_competitor_rating': Decimal('8.2'), 'num_competing_movies': Decimal('2'), 'premium_format_pct': Decimal('0.359'), 'budget_millions': Decimal('5.33'), 'social_media_mentions_k': Decimal('29.9'), 'num_screens': Decimal('2142'), 'director_reputation': Decimal('6'), 'num_theaters': Decimal('1115'), 'rating': 'R', 'theater_chain': 'Alamo Drafthouse', 'franchise_flag': Decimal('1'), 'studio': 'MGM', 'is_weekend_release': Decimal('0'), 'genre': 'Adventure', 'is_summer_release': Decimal('0'), 'star_power_score': Decimal('10'), 'release_date': '2025-03-26', 'urban_theater_pct': Decimal('0.553'), 'is_holiday_release': Decimal('0'), 'audience_score': Decimal('34.1'), 'critic_score': Decimal('55.6'), 'ticket_sales_millions': Decimal('66.08'), 'sequel_flag': Decimal('0')}

# %%
sql_output_d0we = sqlutils.sql("select * from movies limit 10", connection_name="default.sql")
sql_output_d0we
# Out:
#      movie_id  marketing_spend_millions  ...  ticket_sales_millions  sequel_flag
# 0  MOVIE_0251                      3.75  ...                  52.90            0
# 1  MOVIE_0686                     20.51  ...                  88.95            0
# 2  MOVIE_0634                     12.46  ...                  89.88            1
# 3  MOVIE_0940                     11.59  ...                  89.92            0
# 4  MOVIE_0189                      2.63  ...                  66.08            0
# 5  MOVIE_0418                     21.53  ...                 101.76            1
# 6  MOVIE_0330                      2.46  ...                  64.62            1
# 7  MOVIE_0406                      9.38  ...                 106.75            1
# 8  MOVIE_0264                      5.75  ...                  99.09            1
# 9  MOVIE_0711                     10.52  ...                  64.70            0
#
# [10 rows x 26 columns]

# %%
sql_output_6fiu = sqlutils.sql("select * from movies where budget_millions > 25", connection_name="default.sql")
sql_output_6fiu
# Out:
#        movie_id  marketing_spend_millions  ...  ticket_sales_millions  sequel_flag
# 0    MOVIE_0686                     20.51  ...                  88.95            0
# 1    MOVIE_0940                     11.59  ...                  89.92            0
# 2    MOVIE_0418                     21.53  ...                 101.76            1
# 3    MOVIE_0864                     59.75  ...                 173.14            1
# 4    MOVIE_0004                     19.07  ...                  76.80            0
# ..          ...                       ...  ...                    ...          ...
# 187  MOVIE_0147                     41.33  ...                 104.52            0
# 188  MOVIE_0435                     13.55  ...                 102.54            0
# 189  MOVIE_0402                     12.39  ...                 114.61            0
# 190  MOVIE_0061                     52.43  ...                 151.83            1
# 191  MOVIE_0319                     35.36  ...                 152.48            0
#
# [192 rows x 26 columns]
